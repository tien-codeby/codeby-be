# %% [markdown]
# <a href="https://colab.research.google.com/github/tien-codeby/codeby-be/blob/master/B%E1%BA%A3n_sao_c%E1%BB%A7a_Colaboratory_ch%C3%A0o_m%E1%BB%ABng_b%E1%BA%A1n!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#BOXPLOT

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# fake up some data
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low))

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fdd35b47890>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fdd2f632590>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fdd2f6395d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fdd2f639090>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fdd2f624ad0>,
#   <matplotlib.lines.Line2D at 0x7fdd2f632050>]}

# %%
#LINE

# %%
 days = list(range(1,9))

 celsius_values = [25.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]

 plt.plot(days, celsius_values,'--r')

 plt.plot(days,celsius_values, 'sr')

 plt.show()

# %%
#BARPLOT

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
ax.bar(langs,students)
plt.show()

# %%
#SCATTER PLOT

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
#BIỂU ĐỒ y = 3x + 3
plt.plot([3,6,9,12])
plt.show()
# x = 0 => y = 3
# x = 1 => y = 6
# x = 2 => y = 9
# x = 3 => y = 12

# %%
#BIỂU ĐỒ y = x^2 + x + 1
x_1 = np.linspace(start=-3, stop=3, num=100)
print(x_1)
def f(x):
    return x**2 + x + 1
y_1 = f(x_1)
plt.plot(x_1, y_1)
plt.show()
# Out:
# [-3.         -2.93939394 -2.87878788 -2.81818182 -2.75757576 -2.6969697
#  -2.63636364 -2.57575758 -2.51515152 -2.45454545 -2.39393939 -2.33333333
#  -2.27272727 -2.21212121 -2.15151515 -2.09090909 -2.03030303 -1.96969697
#  -1.90909091 -1.84848485 -1.78787879 -1.72727273 -1.66666667 -1.60606061
#  -1.54545455 -1.48484848 -1.42424242 -1.36363636 -1.3030303  -1.24242424
#  -1.18181818 -1.12121212 -1.06060606 -1.         -0.93939394 -0.87878788
#  -0.81818182 -0.75757576 -0.6969697  -0.63636364 -0.57575758 -0.51515152
#  -0.45454545 -0.39393939 -0.33333333 -0.27272727 -0.21212121 -0.15151515
#  -0.09090909 -0.03030303  0.03030303  0.09090909  0.15151515  0.21212121
#   0.27272727  0.33333333  0.39393939  0.45454545  0.51515152  0.57575758
#   0.63636364  0.6969697   0.75757576  0.81818182  0.87878788  0.93939394
#   1.          1.06060606  1.12121212  1.18181818  1.24242424  1.3030303
#   1.36363636  1.42424242  1.48484848  1.54545455  1.60606061  1.66666667
# ...
